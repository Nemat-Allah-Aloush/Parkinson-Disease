# %% [markdown]
# <a href="https://colab.research.google.com/github/Nemat-Allah-Aloush/Advance-Natural-Language-Processing/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading Raw Data
# This step can be skipped, because after reading and editing the format of the datafile, the data was saved and can be read again in the next step.

# %% [markdown]
# ### Demographics of parkinson's patients datafile

# %%
pd_demographics_df = pd.read_excel("/content/drive/MyDrive/Thesis/Data/rawData.xlsx", sheet_name=0, header = [0,1,2])

# %%
# deleting the last column
pd_demographics_df.drop(pd_demographics_df.columns[len(pd_demographics_df.columns)-1], axis=1, inplace=True)

# %%
# Renaming columns
pd_demographics_df.columns = ['PatientNum', 'Assessment_Date','DOB', 'Age', \
'Sex', 'PD_Duration','Yrs_Levodopa_Duration',\
'Sinemet_Dose', 'Sinemet_Conversion', 'Sinemet_CR_Dose',\
'Sinemet_CR_Conversion','Stalevo_Dose','Stalevo_Conversion',\
'Ropinirole_Dose', 'Ropinirole_Conversion','Amantadine_Dose',\
'Amantadine_Conversion', 'Pramipexole_Dose', 'Pramipexole_Conversion',\
'Total_LED','UPDRSOFF','UPDRSON',\
'UPDRS_Response', 'MoCA', 'LeftLeg',\
'RightLeg','FootLen','FootWidth' ,'Weight',\
'Height_FEET','Height_CM']

# %%
# deleting 3 rows for patients with incomplete data
# "PD-25", "PD-54", "PD-66"
pd_demographics_df.drop(pd_demographics_df.index[(pd_demographics_df["PatientNum"] == "PD-25")],axis=0,inplace=True)

# %%
pd_demographics_df.drop(pd_demographics_df.index[(pd_demographics_df["PatientNum"] == "PD-54")],axis=0,inplace=True)

# %%
pd_demographics_df.drop(pd_demographics_df.index[(pd_demographics_df["PatientNum"] == "PD-66")],axis=0,inplace=True)

# %%
# deleting last two rows that contain staticts not data records
pd_demographics_df.drop(pd_demographics_df.tail(2).index, inplace = True)

# %%
pd_demographics_df.tail()
# Out:
#    PatientNum Assessment_Date                  DOB   Age Sex  PD_Duration  \
# 60      PD-66      2017-01-10  1962-07-08 00:00:00  54.0   F         16.0
# 61      PD-67      2017-01-16  1949-04-08 00:00:00  67.0   M         11.0
# 62      PD-68      2017-01-19  1952-12-16 00:00:00  64.0   M          8.0
# 63      PD-69      2017-01-30  1943-10-18 00:00:00  73.0   F         12.0
# 64      PD-70      2017-02-08  1954-12-21 00:00:00  62.0   M          3.0
#
#     Yrs_Levodopa_Duration  Sinemet_Dose  Sinemet_Conversion  Sinemet_CR_Dose  \
# 60                   16.0         500.0               500.0              NaN
# 61                   11.0         400.0               400.0              NaN
# 62                    8.0           NaN                 0.0              NaN
# 63                   10.0        1000.0              1000.0            200.0
# 64                    2.0         600.0               600.0              NaN
#
# ...

# %%
# saving data
pd_demographics_df.to_csv('/content/drive/MyDrive/Thesis/Data/pd_demographics.csv',index=False)

# %% [markdown]
# ### Control Demographics datafile

# %%
control_demographics_df = pd.read_excel("/content/drive/MyDrive/Thesis/Data/rawData.xlsx", sheet_name=1, header = [0,1,2])

# %%
# deleting last two rows that contain staticts not data records
control_demographics_df.drop(control_demographics_df.tail(2).index, inplace = True)

# %%
# Renaming columns
control_demographics_df.columns = ['PatientNum', 'Assessment_Date','DOB', 'Age', \
'Sex', 'MoCA', 'LeftLeg',\
'RightLeg','FootLen','FootWidth' ,'Weight',\
'Height_FEET','Height_CM']

# %%
# saving data
control_demographics_df.to_csv('/content/drive/MyDrive/Thesis/Data/control_demographics.csv', index = False)

# %% [markdown]
# ### Control Gait datafile

# %%
control_gait_df = pd.read_excel("/content/drive/MyDrive/Thesis/Data/rawData.xlsx", sheet_name=2, header = [0,1,2])

# %%
# renaming colomns
control_gait_df.columns = ['id','Full_Name','Reference', 
 'StepVelocityMean', 'StepVelocitySD', 'StepVelocityCV'
, 'StepLengthMean', 'StepLengthSD', 'StepLengthCV', 'StepLengthAsym',
 'StepWidthMean', 'StepWidthSD', 'StepTimeMean', 'StepTimeSD', 'StepTimeCV'
, 'StepTimeAsym', 'StanceTimeMean', 'StanceTimeSD', 'StanceTimeCV',
'StanceTimeAsym', 'SwingTimeMean', 'SwingTimeSD', 'SwingTimeCV', 'SwingTimeAsym',
'Mean_GVI', 'WalkRatio']

# %%
# deleting 1 empty row
control_gait_df = control_gait_df.drop(11)

# %%
control_gait_df.head()
# Out:
#     id         Full_Name    Reference  StepVelocityMean  StepVelocitySD  \
# 0  1.0  Control, PD-101   Ctrl Normal           1.27350         0.04114
# 1  2.0  Control, PD-102   Ctrl Normal           1.40979         0.03882
# 2  3.0  Control, PD-103   Ctrl Normal           1.48036         0.03300
# 3  4.0  Control, PD-104   Ctrl Normal           1.29350         0.06010
# 4  5.0  Control, PD-107   Ctrl Normal           1.45916         0.04631
#
#    StepVelocityCV  StepLengthMean  StepLengthSD  StepLengthCV  StepLengthAsym  \
# 0           3.230         0.67894       0.01867         2.749         0.00939
# 1           2.753         0.64162       0.01373         2.140         0.00728
# 2           2.229         0.68223       0.01240         1.817         0.00051
# 3           4.647         0.66023       0.02193         3.322         0.00007
# 4           3.174         0.67105       0.02079         3.098         0.00067
#
# ...

# %%
# saving data
control_gait_df.to_csv('/content/drive/MyDrive/Thesis/Data/control_gait.csv', index = False)

# %% [markdown]
# ### PD OFF NORMAL datafile

# %%
pd_off_noraml_df = pd.read_excel("/content/drive/MyDrive/Thesis/Data/rawData.xlsx", sheet_name=3, header = [0,1,2])

# %%
pd_off_noraml_df.tail()
# Out:
#    Unnamed: 0_level_0          Full Name          Reference  \
#    Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
#    Unnamed: 0_level_2 Unnamed: 1_level_2 Unnamed: 2_level_2
# 62               63.0         PD, PD-68        Normal - Pre
# 63               64.0         PD, PD-69        Normal - Pre
# 64               65.0         PD, PD-70        Normal - Pre
# 65                NaN                NaN                NaN
# 66                NaN                NaN                NaN
#
#    Step Velocity (m./sec.)                               Step Length (m.)  \
#                       Mean           S.D.         C.V. %             Mean
#               StepVelocity StepVelocitySD StepVelocityCV       StepLength
# 62                0.539090       0.031930       5.923000         0.394150
# 63                0.681220       0.079540      11.677000         0.378550
# 64                1.106680       0.039560       3.575000         0.634780
# ...

# %%
# deleting the last column
pd_off_noraml_df.drop(pd_off_noraml_df.columns[len(pd_off_noraml_df.columns)-1], axis=1, inplace=True)

# %%
# renaming colomns
pd_off_noraml_df.columns = ['id','Full_Name','Reference', 
 'StepVelocityMean', 'StepVelocitySD', 'StepVelocityCV'
, 'StepLengthMean', 'StepLengthSD', 'StepLengthCV', 'StepLengthAsym',
 'StepWidthMean', 'StepWidthSD', 'StepTimeMean', 'StepTimeSD', 'StepTimeCV'
, 'StepTimeAsym', 'StanceTimeMean', 'StanceTimeSD', 'StanceTimeCV',
'StanceTimeAsym', 'SwingTimeMean', 'SwingTimeSD', 'SwingTimeCV', 'SwingTimeAsym','Mean_GVI', 'WalkRatio']

# %%
# deleting 3 rows for patients with incomplete data
# "PD-25", "PD-54", "PD-66"
pd_off_noraml_df.drop(pd_off_noraml_df.index[(pd_off_noraml_df["id"] == 21.0)],axis=0,inplace=True)
pd_off_noraml_df.drop(pd_off_noraml_df.index[(pd_off_noraml_df["id"] == 49.0)],axis=0,inplace=True)
pd_off_noraml_df.drop(pd_off_noraml_df.index[(pd_off_noraml_df["id"] == 61.0)],axis=0,inplace=True)

# %%
# deleting the last 2 rows
pd_off_noraml_df.drop(pd_off_noraml_df.tail(2).index,inplace=True)

# %%
pd_off_noraml_df.tail()
# Out:
#       id   Full_Name     Reference  StepVelocityMean  StepVelocitySD  \
# 59  60.0  PD, PD-65   Normal - Pre           0.91393         0.03892
# 61  62.0  PD, PD-67   Normal - Pre           1.06420         0.08296
# 62  63.0  PD, PD-68   Normal - Pre           0.53909         0.03193
# 63  64.0  PD, PD-69   Normal - Pre           0.68122         0.07954
# 64  65.0  PD, PD-70   Normal - Pre           1.10668         0.03956
#
#     StepVelocityCV  StepLengthMean  StepLengthSD  StepLengthCV  \
# 59           4.259         0.49814       0.05445        10.930
# 61           7.796         0.57672       0.03455         5.992
# 62           5.923         0.39415       0.03730         9.463
# 63          11.677         0.37855       0.04426        11.691
# 64           3.575         0.63478       0.02068         3.257
#
#     StepLengthAsym  ...  StanceTimeMean  StanceTimeSD  StanceTimeCV  \
# 59         0.09807  ...           729.0          18.0         2.493
# ...

# %%
# saving data
pd_off_noraml_df.to_csv('/content/drive/MyDrive/Thesis/Data/pd_off_noraml.csv', index = False)

# %% [markdown]
# ### PD OFF Backward datafile

# %%
pd_off_backward_df = pd.read_excel("/content/drive/MyDrive/Thesis/Data/rawData.xlsx", sheet_name=4, header = [0,1,2])

# %%
# deleting the last column
pd_off_backward_df.drop(pd_off_backward_df.columns[len(pd_off_backward_df.columns)-1], axis=1, inplace=True)

# %%
# renaming colomns
pd_off_backward_df.columns = ['id','Full_Name','Reference', 
 'StepVelocityMean', 'StepVelocitySD', 'StepVelocityCV'
, 'StepLengthMean', 'StepLengthSD', 'StepLengthCV', 'StepLengthAsym',
 'StepWidthMean', 'StepWidthSD', 'StepTimeMean', 'StepTimeSD', 'StepTimeCV'
, 'StepTimeAsym', 'StanceTimeMean', 'StanceTimeSD', 'StanceTimeCV',
'StanceTimeAsym', 'SwingTimeMean', 'SwingTimeSD', 'SwingTimeCV', 'SwingTimeAsym','Mean_GVI', 'WalkRatio']

# %%
# deleting 3 rows for patients with incomplete data
# "PD-25", "PD-54", "PD-66"
pd_off_backward_df.drop(pd_off_backward_df.index[(pd_off_backward_df["Full_Name"] == "PD, PD-25")],axis=0,inplace=True)
pd_off_backward_df.drop(pd_off_backward_df.index[(pd_off_backward_df["Full_Name"] == "PD, PD-54")],axis=0,inplace=True)
pd_off_backward_df.drop(pd_off_backward_df.index[(pd_off_backward_df["Full_Name"] == "PD, PD-66")],axis=0,inplace=True)

# %%
pd_off_backward_df.drop(pd_off_backward_df.tail(2).index,inplace=True)

# %%
pd_off_backward_df.tail()
# Out:
#       id   Full_Name        Reference  StepVelocityMean  StepVelocitySD  \
# 60  61.0  PD, PD-66   Backwards - Pre               NaN             NaN
# 61  62.0  PD, PD-67   Backwards - Pre          0.625250        0.105380
# 62  63.0  PD, PD-68   Backwards - Pre          0.191300        0.034895
# 63  64.0  PD, PD-69   Backwards - Pre          0.365890        0.055030
# 64  65.0  PD, PD-70   Backwards - Pre          0.653485        0.076150
#
#     StepVelocityCV  StepLengthMean  StepLengthSD  StepLengthCV  \
# 60             NaN             NaN           NaN           NaN
# 61         16.8115        0.306305      0.050085       16.3935
# 62         18.6115        0.131170      0.052670       40.8365
# 63         15.2025        0.222435      0.057700       26.0115
# 64         12.1765        0.433490      0.056955       13.4915
#
#     StepLengthAsym  ...  StanceTimeMean  StanceTimeSD  StanceTimeCV  \
# 60             NaN  ...             NaN           NaN           NaN
# ...

# %%
# saving data
pd_off_backward_df.to_csv('/content/drive/MyDrive/Thesis/Data/pd_off_backward.csv', index = False)

# %% [markdown]
# ### PD ON NORMAL datafile

# %%
pd_on_noraml_df = pd.read_excel("/content/drive/MyDrive/Thesis/Data/rawData.xlsx", sheet_name=5, header = [0,1,2])

# %%
# deleting the last column
pd_on_noraml_df.drop(pd_on_noraml_df.columns[len(pd_on_noraml_df.columns)-1], axis=1, inplace=True)

# %%
# renaming colomns
pd_on_noraml_df.columns = ['id','Full_Name','Reference', 
 'StepVelocityMean', 'StepVelocitySD', 'StepVelocityCV'
, 'StepLengthMean', 'StepLengthSD', 'StepLengthCV', 'StepLengthAsym',
 'StepWidthMean', 'StepWidthSD', 'StepTimeMean', 'StepTimeSD', 'StepTimeCV'
, 'StepTimeAsym', 'StanceTimeMean', 'StanceTimeSD', 'StanceTimeCV',
'StanceTimeAsym', 'SwingTimeMean', 'SwingTimeSD', 'SwingTimeCV', 'SwingTimeAsym','Mean_GVI', 'WalkRatio']

# %%
# deleting 3 rows for patients with incomplete data
# "PD-25", "PD-54", "PD-66"
pd_on_noraml_df.drop(pd_on_noraml_df.index[(pd_on_noraml_df["id"] == 21.0)],axis=0,inplace=True)
pd_on_noraml_df.drop(pd_on_noraml_df.index[(pd_on_noraml_df["id"] == 49.0)],axis=0,inplace=True)
pd_on_noraml_df.drop(pd_on_noraml_df.index[(pd_on_noraml_df["id"] == 61.0)],axis=0,inplace=True)

# %%
# deleting the last 2 rows
pd_on_noraml_df.drop(pd_on_noraml_df.tail(2).index,inplace=True)

# %%
pd_on_noraml_df.tail()
# Out:
#       id   Full_Name      Reference  StepVelocityMean  StepVelocitySD  \
# 59  60.0  PD, PD-65   Normal - Post           0.96731         0.05986
# 61  62.0  PD, PD-67   Normal - Post           1.22489         0.06071
# 62  63.0  PD, PD-68   Normal - Post           0.91574         0.05029
# 63  64.0  PD, PD-69   Normal - Post           0.97688         0.06543
# 64  65.0  PD, PD-70   Normal - Post           1.10330         0.04680
#
#     StepVelocityCV  StepLengthMean  StepLengthSD  StepLengthCV  \
# 59           6.189         0.53257       0.06040        11.341
# 61           4.956         0.65127       0.06333         9.724
# 62           5.491         0.57545       0.04404         7.653
# 63           6.698         0.47228       0.03447         7.299
# 64           4.242         0.63107       0.02362         3.742
#
#     StepLengthAsym  ...  StanceTimeMean  StanceTimeSD  StanceTimeCV  \
# 59         0.10585  ...           740.0          22.0         2.987
# ...

# %%
# saving data
pd_on_noraml_df.to_csv('/content/drive/MyDrive/Thesis/Data/pd_on_noraml.csv', index = False)

# %% [markdown]
# ### PD ON Backward datafile

# %%
pd_on_backward_df = pd.read_excel("/content/drive/MyDrive/Thesis/Data/rawData.xlsx", sheet_name=6, header = [0,1,2])

# %%
# deleting the last column
pd_on_backward_df.drop(pd_on_backward_df.columns[len(pd_on_backward_df.columns)-1], axis=1, inplace=True)

# %%
# renaming colomns
pd_on_backward_df.columns = ['id','Full_Name','Reference', 
 'StepVelocityMean', 'StepVelocitySD', 'StepVelocityCV'
, 'StepLengthMean', 'StepLengthSD', 'StepLengthCV', 'StepLengthAsym',
 'StepWidthMean', 'StepWidthSD', 'StepTimeMean', 'StepTimeSD', 'StepTimeCV'
, 'StepTimeAsym', 'StanceTimeMean', 'StanceTimeSD', 'StanceTimeCV',
'StanceTimeAsym', 'SwingTimeMean', 'SwingTimeSD', 'SwingTimeCV', 'SwingTimeAsym','Mean_GVI', 'WalkRatio']

# %%
# deleting 3 rows for patients with incomplete data
# "PD-25", "PD-54", "PD-66"
pd_on_backward_df.drop(pd_on_backward_df.index[(pd_on_backward_df["Full_Name"] == "PD, PD-25")],axis=0,inplace=True)
pd_on_backward_df.drop(pd_on_backward_df.index[(pd_on_backward_df["Full_Name"] == "PD, PD-54")],axis=0,inplace=True)
pd_on_backward_df.drop(pd_on_backward_df.index[(pd_on_backward_df["Full_Name"] == "PD, PD-66")],axis=0,inplace=True)

# %%
pd_on_backward_df.tail()
# Out:
#       id   Full_Name         Reference  StepVelocityMean  StepVelocitySD  \
# 60  61.0  PD, PD-66   Backwards - Post               NaN             NaN
# 61  62.0  PD, PD-67   Backwards - Post          0.727135         0.11065
# 62  63.0  PD, PD-68   Backwards - Post          0.464235         0.08367
# 63  64.0  PD, PD-69   Backwards - Post          0.773420         0.12777
# 64  65.0  PD, PD-70   Backwards - Post          0.706160         0.06771
#
#     StepVelocityCV  StepLengthMean  StepLengthSD  StepLengthCV  \
# 60             NaN             NaN           NaN           NaN
# 61         15.1915        0.336440      0.055855        16.605
# 62         17.9795        0.325595      0.067080        20.636
# 63         16.4935        0.319940      0.085635        26.872
# 64          9.5340        0.440305      0.054770        12.438
#
#     StepLengthAsym  ...  StanceTimeMean  StanceTimeSD  StanceTimeCV  \
# 60             NaN  ...             NaN           NaN           NaN
# ...

# %%
# saving data
pd_on_backward_df.to_csv('/content/drive/MyDrive/Thesis/Data/pd_on_backward.csv', index = False)

# %% [markdown]
# ## Reading reformated file

# %%
# 1
pd_demographics_df=pd.read_csv('/content/drive/MyDrive/Thesis/Data/pd_demographics.csv')
# 2
control_demographics_df=pd.read_csv('/content/drive/MyDrive/Thesis/Data/control_demographics.csv')
# 3
control_gait_df=pd.read_csv('/content/drive/MyDrive/Thesis/Data/control_gait.csv')
# 4
pd_off_noraml_df=pd.read_csv('/content/drive/MyDrive/Thesis/Data/pd_off_noraml.csv')
# 5
pd_off_backward_df=pd.read_csv('/content/drive/MyDrive/Thesis/Data/pd_off_backward.csv')
# 6
pd_on_noraml_df=pd.read_csv('/content/drive/MyDrive/Thesis/Data/pd_on_noraml.csv')
# 7
pd_on_backward_df=pd.read_csv('/content/drive/MyDrive/Thesis/Data/pd_on_backward.csv')

# %%
pd_demographics_df.head()
# Out:
#   PatientNum Assessment_Date                  DOB   Age Sex  PD_Duration  \
# 0      PD-01      2015-09-16  1958-03-20 00:00:00  57.0   M          8.0
# 1      PD-02      2015-11-02  1950-10-04 00:00:00  65.0   M         12.0
# 2      PD-03      2015-11-01  1946-06-21 00:00:00  69.0   F         16.0
# 3      PD-04      2015-11-09  1956-07-24 00:00:00  59.0   F          7.0
# 4      PD-05      2015-11-11  1951-12-24 00:00:00  63.0   M          7.0
#
#    Yrs_Levodopa_Duration  Sinemet_Dose  Sinemet_Conversion  Sinemet_CR_Dose  \
# 0                    8.0         750.0               750.0            200.0
# 1                   11.0        1000.0              1000.0            200.0
# 2                   12.0         600.0               600.0              NaN
# 3                    6.0         420.0               420.0              NaN
# 4                    7.0         800.0               800.0            200.0
#
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Checking Null (missing) values
data_df.isnull().sum()
# Out:
# Unnamed: 0_level_0     Unnamed: 0_level_1    PatientNum              0
# Assessment Date        Unnamed: 1_level_1    Assessment              0
# DOB                    Unnamed: 2_level_1    DOB                     0
# Age                    Unnamed: 3_level_1    Age                     0
# Sex                    Unnamed: 4_level_1    Sex                     0
# PD Duration            Unnamed: 5_level_1    Duration                0
# Yrs On Levodopa        Unnamed: 6_level_1    LevodopaDuration        0
#                        Unnamed: 7_level_1    LevodopaDuration       65
#                        Unnamed: 8_level_1    LevodopaDuration       65
# Sinemet                Dose                  Sinmet                  1
#                        Conversion (x1)       Unnamed: 10_level_2     0
# Sinemet CR             Dose                  SinemetCR              54
#                        Conversion (x.75)     Unnamed: 12_level_2     2
# ...

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Statical measurements

# %% [markdown]
# #### PD Demographics

# %%
Female_count = pd_demographics_df['Sex'].eq('F').sum(axis=0)
print(f'Number of Female PD patients = {Female_count}')
pd_count = pd_demographics_df.shape[0]
print(f'Number of PD patients = {pd_count}')
Female_precentage = Female_count*100/pd_count
print (f'Precentage of Female patients = {Female_precentage}%')
# Out:
# Number of Female PD patients = 19
# Number of PD patients = 62
# Precentage of Female patients = 30.64516129032258%

# %%
pd_demographics_df.describe()
# Out:
#              Age  PD_Duration  Yrs_Levodopa_Duration  Sinemet_Dose  \
# count  62.000000    62.000000              62.000000     61.000000
# mean   65.290323     8.991935               7.137097    803.114754
# std     7.170950     4.113644               3.965186    315.850919
# min    47.000000     3.000000               1.000000    300.000000
# 25%    60.000000     5.000000               4.250000    600.000000
# 50%    66.000000     8.000000               6.000000    800.000000
# 75%    71.000000    12.000000              10.000000   1000.000000
# max    82.000000    18.000000              17.000000   1600.000000
#
#        Sinemet_Conversion  Sinemet_CR_Dose  Sinemet_CR_Conversion  \
# count            62.00000             10.0              60.000000
# mean            790.16129            200.0              25.000000
# std             329.43813              0.0              56.373452
# min               0.00000            200.0               0.000000
# ...

# %%
statics = pd_demographics_df.describe()
l = round(statics.iloc[1],3).astype(str) + ' ± '+ round(statics.iloc[2],3).astype(str)
l
# Out:
# Age                           65.29 ± 7.171
# PD_Duration                   8.992 ± 4.114
# Yrs_Levodopa_Duration         7.137 ± 3.965
# Sinemet_Dose              803.115 ± 315.851
# Sinemet_Conversion        790.161 ± 329.438
# Sinemet_CR_Dose                 200.0 ± 0.0
# Sinemet_CR_Conversion         25.0 ± 56.373
# Stalevo_Dose                862.5 ± 349.702
# Stalevo_Conversion          19.297 ± 76.792
# Ropinirole_Dose                   nan ± nan
# Ropinirole_Conversion             0.0 ± 0.0
# Amantadine_Dose               200.0 ± 81.65
# Amantadine_Conversion       48.333 ± 96.536
# Pramipexole_Dose              3.028 ± 1.753
# Pramipexole_Conversion     89.344 ± 167.609
# Total_LED                 967.395 ± 431.479
# UPDRSOFF                     29.677 ± 9.884
# UPDRSON                      16.403 ± 8.211
# UPDRS_Response               29.135 ± 9.854
# MoCA                         25.387 ± 3.619
# LeftLeg                      96.533 ± 5.874
# ...

# %% [markdown]
# #### Control Demographics

# %%
CFemale_count = control_demographics_df['Sex'].eq('F').sum(axis=0)
print(f'Number of Female PD patients = {CFemale_count}')
C_count = control_demographics_df.shape[0]
print(f'Number of PD patients = {C_count}')
CFemale_precentage = CFemale_count*100/C_count
print (f'Precentage of Female patients = {CFemale_precentage}%')
# Out:
# Number of Female PD patients = 4
# Number of PD patients = 11
# Precentage of Female patients = 36.36363636363637%

# %%
control_demographics_df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Age           63.090909
# MoCA          26.272727
# LeftLeg       96.545455
# RightLeg      96.545455
# FootLen       24.863636
# FootWidth     11.181818
# Weight       181.000000
# Height_CM    172.027273
# dtype: float64

# %%
control_demographics_df.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Age           8.092645
# MoCA          2.148996
# LeftLeg       7.090326
# RightLeg      7.090326
# FootLen       1.898564
# FootWidth     4.551224
# Weight       28.792360
# Height_CM     9.022608
# dtype: float64

# %% [markdown]
# #### Gait Control

# %%
control_gait_normal=control_gait_df.iloc[0:11]

# %%
control_gait_normal.describe()
# Out:
#               id  StepVelocityMean  StepVelocitySD  StepVelocityCV  \
# count  11.000000         11.000000       11.000000       11.000000
# mean    6.000000          1.280919        0.049637        3.998545
# std     3.316625          0.171021        0.009540        1.172388
# min     1.000000          1.012060        0.033000        2.229000
# 25%     3.500000          1.179165        0.043725        3.202000
# 50%     6.000000          1.273500        0.050130        3.971000
# 75%     8.500000          1.434475        0.056350        5.018000
# max    11.000000          1.509100        0.064510        5.609000
#
#        StepLengthMean  StepLengthSD  StepLengthCV  StepLengthAsym  \
# count       11.000000     11.000000     11.000000       11.000000
# mean         0.641763      0.019887      3.124091        0.010956
# std          0.059093      0.004844      0.816581        0.010229
# min          0.538330      0.012400      1.817000        0.000070
# ...

# %%
statics = control_gait_normal.describe()
l = round(statics.iloc[1],3).astype(str) + ' ± '+ round(statics.iloc[2],3).astype(str)
l
# Out:
# id                       6.0 ± 3.317
# StepVelocityMean       1.281 ± 0.171
# StepVelocitySD           0.05 ± 0.01
# StepVelocityCV         3.999 ± 1.172
# StepLengthMean         0.642 ± 0.059
# StepLengthSD            0.02 ± 0.005
# StepLengthCV           3.124 ± 0.817
# StepLengthAsym          0.011 ± 0.01
# StepWidthMean          0.092 ± 0.019
# StepWidthSD            0.019 ± 0.005
# StepTimeMean        505.909 ± 43.233
# StepTimeSD              15.0 ± 5.899
# StepTimeCV             2.946 ± 1.032
# StepTimeAsym            9.727 ± 8.51
# StanceTimeMean      629.818 ± 60.178
# StanceTimeSD          17.909 ± 7.436
# StanceTimeCV           2.811 ± 1.044
# StanceTimeAsym         5.727 ± 5.159
# SwingTimeMean       382.545 ± 27.167
# SwingTimeSD           12.455 ± 3.984
# SwingTimeCV             3.21 ± 0.992
# SwingTimeAsym          4.818 ± 3.995
# Mean_GVI              97.244 ± 4.254
# WalkRatio               0.541 ± 0.06
# dtype: object

# %%
control_gait_bw=control_gait_df.iloc[11:]
control_gait_bw
# Out:
#       id         Full_Name      Reference  StepVelocityMean  StepVelocitySD  \
# 11   1.0  Control, PD-101   Ctrl Backward          1.034340        0.136595
# 12   2.0   Control, PD-102  Ctrl Backward          0.889665        0.109250
# 13   3.0  Control, PD-103   Ctrl Backward          1.354160        0.070645
# 14   4.0  Control, PD-104   Ctrl Backward          0.922835        0.108830
# 15   5.0  Control, PD-107   Ctrl Backward          1.334975        0.077650
# 16   6.0  Control, PD-108   Ctrl Backward          1.122515        0.115050
# 17   7.0  Control, PD-109   Ctrl Backward          0.786290        0.079790
# 18   8.0  Control, PD-111   Ctrl Backward          0.973875        0.115040
# 19   9.0  Control, PD-112   Ctrl Backward          0.602395        0.093880
# 20  10.0  Control, PD-113   Ctrl Backward          1.227800        0.166090
# 21  11.0  Control, PD-114   Ctrl Backward          0.795235        0.065755
#
# ...

# %%
control_gait_bw.describe()
# Out:
#               id  StepVelocityMean  StepVelocitySD  StepVelocityCV  \
# count  11.000000         11.000000       11.000000       11.000000
# mean    6.000000          1.004008        0.103507       10.707091
# std     3.316625          0.238756        0.030279        3.215171
# min     1.000000          0.602395        0.065755        5.234000
# 25%     3.500000          0.842450        0.078720        9.155250
# 50%     6.000000          0.973875        0.108830       11.798000
# 75%     8.500000          1.175158        0.115045       12.722500
# max    11.000000          1.354160        0.166090       15.581500
#
#        StepLengthMean  StepLengthSD  StepLengthCV  StepLengthAsym  \
# count       11.000000     11.000000     11.000000       11.000000
# mean         0.481367      0.058499     12.518955        0.035049
# std          0.099016      0.024511      4.664470        0.028829
# min          0.351600      0.024810      4.001000        0.010635
# ...

# %%
statics = control_gait_bw.describe()
l = round(statics.iloc[1],3).astype(str) + ' ± '+ round(statics.iloc[2],3).astype(str)
l
# Out:
# id                       6.0 ± 3.317
# StepVelocityMean       1.004 ± 0.239
# StepVelocitySD          0.104 ± 0.03
# StepVelocityCV        10.707 ± 3.215
# StepLengthMean         0.481 ± 0.099
# StepLengthSD           0.058 ± 0.025
# StepLengthCV          12.519 ± 4.664
# StepLengthAsym         0.035 ± 0.029
# StepWidthMean          0.207 ± 0.055
# StepWidthSD            0.032 ± 0.006
# StepTimeMean        488.773 ± 51.045
# StepTimeSD            24.682 ± 6.871
# StepTimeCV             5.028 ± 1.149
# StepTimeAsym            8.545 ± 6.17
# StanceTimeMean      637.682 ± 71.219
# StanceTimeSD           39.0 ± 10.766
# StanceTimeCV           6.093 ± 1.445
# StanceTimeAsym         11.5 ± 11.364
# SwingTimeMean       343.909 ± 33.861
# SwingTimeSD             24.5 ± 6.423
# SwingTimeCV            7.141 ± 1.848
# SwingTimeAsym         10.364 ± 8.872
# Mean_GVI             131.585 ± 8.285
# WalkRatio              0.391 ± 0.077
# dtype: object

# %%
l.to_csv("/content/drive/MyDrive/Thesis/Data/l.csv")

# %% [markdown]
# #### PD ON FORWARD

# %%
pd_on_noraml_df.describe()
# Out:
#               id  StepVelocityMean  StepVelocitySD  StepVelocityCV  \
# count  62.000000         62.000000       62.000000       62.000000
# mean   32.483871          1.199396        0.053340        4.643500
# std    18.852092          0.190508        0.021905        2.290883
# min     1.000000          0.567450        0.022250        1.833000
# 25%    16.250000          1.065748        0.040885        3.052250
# 50%    32.500000          1.230380        0.046750        4.064500
# 75%    47.750000          1.343670        0.061183        5.254000
# max    65.000000          1.544960        0.130720       13.407000
#
#        StepLengthMean  StepLengthSD  StepLengthCV  StepLengthAsym  \
# count       62.000000     62.000000     62.000000       62.000000
# mean         0.608075      0.030208      5.196468        0.028474
# std          0.090549      0.011168      2.398002        0.024206
# min          0.258830      0.012390      1.723000        0.000530
# ...

# %%
statics = pd_on_noraml_df.describe()
l = round(statics.iloc[1],3).astype(str) + ' ± '+ round(statics.iloc[2],3).astype(str)
l
# Out:
# id                   32.484 ± 18.852
# StepVelocityMean       1.199 ± 0.191
# StepVelocitySD         0.053 ± 0.022
# StepVelocityCV         4.643 ± 2.291
# StepLengthMean         0.608 ± 0.091
# StepLengthSD            0.03 ± 0.011
# StepLengthCV           5.196 ± 2.398
# StepLengthAsym         0.028 ± 0.024
# StepWidthMean          0.084 ± 0.032
# StepWidthSD             0.024 ± 0.01
# StepTimeMean         510.21 ± 44.721
# StepTimeSD              20.5 ± 8.772
# StepTimeCV             4.047 ± 1.774
# StepTimeAsym          18.274 ± 16.22
# StanceTimeMean      641.548 ± 62.155
# StanceTimeSD         24.952 ± 20.596
# StanceTimeCV           3.858 ± 2.816
# StanceTimeAsym       13.984 ± 11.513
# SwingTimeMean       380.774 ± 34.652
# SwingTimeSD           17.629 ± 7.751
# SwingTimeCV            4.691 ± 2.124
# SwingTimeAsym        13.742 ± 11.915
# Mean_GVI             108.069 ± 12.53
# WalkRatio               0.52 ± 0.097
# dtype: object

# %%
l.to_csv("/content/drive/MyDrive/Thesis/Data/l.csv")

# %% [markdown]
# #### PD OFF BACKWARD

# %%
pd_off_backward_df.describe()
# Out:
#               id  StepVelocityMean  StepVelocitySD  StepVelocityCV  \
# count  64.000000         62.000000       62.000000       62.000000
# mean   32.750000          0.630338        0.081356       14.292567
# std    18.948552          0.217038        0.027544        6.508425
# min     1.000000          0.183170        0.034895        5.996500
# 25%    16.750000          0.501464        0.063305       10.397625
# 50%    32.500000          0.621945        0.076175       13.162000
# 75%    48.500000          0.775350        0.095784       16.302250
# max    65.000000          1.182423        0.209143       47.412000
#
#        StepLengthMean  StepLengthSD  StepLengthCV  StepLengthAsym  \
# count       62.000000     62.000000     62.000000       62.000000
# mean         0.300842      0.054026     21.507801        0.045549
# std          0.105460      0.014862     15.000654        0.038600
# min          0.076060      0.030790      7.190500        0.001035
# ...

# %%
statics = pd_off_backward_df.describe()
l = round(statics.iloc[1],3).astype(str) + ' ± '+ round(statics.iloc[2],3).astype(str)
l
# Out:
# id                     32.75 ± 18.949
# StepVelocityMean         0.63 ± 0.217
# StepVelocitySD          0.081 ± 0.028
# StepVelocityCV         14.293 ± 6.508
# StepLengthMean          0.301 ± 0.105
# StepLengthSD            0.054 ± 0.015
# StepLengthCV          21.508 ± 15.001
# StepLengthAsym          0.046 ± 0.039
# StepWidthMean           0.197 ± 0.043
# StepWidthSD             0.023 ± 0.014
# StepTimeMean         486.634 ± 81.455
# StepTimeSD            37.565 ± 16.075
# StepTimeCV              7.859 ± 3.715
# StepTimeAsym          19.728 ± 15.111
# StanceTimeMean      664.828 ± 111.172
# StanceTimeSD          57.129 ± 34.678
# StanceTimeCV             8.657 ± 5.42
# StanceTimeAsym        21.285 ± 16.131
# SwingTimeMean        312.653 ± 66.254
# SwingTimeSD           35.414 ± 14.126
# SwingTimeCV             11.982 ± 6.11
# SwingTimeAsym         19.102 ± 14.127
# Mean_GVI               139.38 ± 8.112
# WalkRatio               0.249 ± 0.106
# dtype: object

# %% [markdown]
# #### PD ON BACWARD

# %%
pd_on_backward_df.describe()
# Out:
#               id  StepVelocityMean  StepVelocitySD  StepVelocityCV  \
# count  64.000000         62.000000       62.000000       62.000000
# mean   32.750000          0.805445        0.090001       12.210097
# std    18.948552          0.218355        0.020230        5.109774
# min     1.000000          0.246650        0.055745        5.342500
# 25%    16.750000          0.696298        0.071896        9.105750
# 50%    32.500000          0.810090        0.087892       11.520750
# 75%    48.500000          0.953346        0.104665       14.030375
# max    65.000000          1.216540        0.161805       35.694000
#
#        StepLengthMean  StepLengthSD  StepLengthCV  StepLengthAsym  \
# count       62.000000     62.000000     62.000000       62.000000
# mean         0.371914      0.061997     19.171524        0.054270
# std          0.097817      0.017609     13.787489        0.042462
# min          0.094220      0.032545      6.944000        0.003430
# ...

# %%
statics = pd_on_backward_df.describe()
l = round(statics.iloc[1],3).astype(str) + ' ± '+ round(statics.iloc[2],3).astype(str)
l
# Out:
# id                     32.75 ± 18.949
# StepVelocityMean        0.805 ± 0.218
# StepVelocitySD            0.09 ± 0.02
# StepVelocityCV           12.21 ± 5.11
# StepLengthMean          0.372 ± 0.098
# StepLengthSD            0.062 ± 0.018
# StepLengthCV          19.172 ± 13.787
# StepLengthAsym          0.054 ± 0.042
# StepWidthMean            0.196 ± 0.05
# StepWidthSD             0.029 ± 0.015
# StepTimeMean         474.032 ± 82.595
# StepTimeSD             35.621 ± 17.14
# StepTimeCV              7.608 ± 3.765
# StepTimeAsym          23.952 ± 22.631
# StanceTimeMean      631.121 ± 114.105
# StanceTimeSD          49.129 ± 21.656
# StanceTimeCV             7.843 ± 3.37
# StanceTimeAsym        21.403 ± 16.135
# SwingTimeMean        320.129 ± 62.312
# SwingTimeSD           32.363 ± 12.952
# SwingTimeCV            10.471 ± 4.797
# SwingTimeAsym         20.589 ± 14.187
# Mean_GVI              137.549 ± 9.645
# WalkRatio               0.297 ± 0.101
# dtype: object

# %%
l.to_csv("/content/drive/MyDrive/Thesis/Data/l.csv")

# %% [markdown]
# #### PD OFF FORWARD

# %%
pd_off_noraml_df.describe()
# Out:
#               id  StepVelocityMean  StepVelocitySD  StepVelocityCV  \
# count  62.000000         62.000000       62.000000       62.000000
# mean   32.483871          0.994276        0.055616        6.626790
# std    18.852092          0.259136        0.025434        5.451277
# min     1.000000          0.057000        0.016630        2.477000
# 25%    16.250000          0.879270        0.039732        3.665750
# 50%    32.500000          1.052960        0.047565        4.989000
# 75%    47.750000          1.171650        0.063357        7.361250
# max    65.000000          1.368710        0.151750       31.717000
#
#        StepLengthMean  StepLengthSD  StepLengthCV  StepLengthAsym  \
# count       62.000000     62.000000     62.000000       62.000000
# mean         0.515169      0.033077      7.856597        0.028427
# std          0.127374      0.014136      7.144236        0.024791
# min          0.060680      0.013670      2.276000        0.003200
# ...

# %%
statics = pd_off_noraml_df.describe()
l = round(statics.iloc[1],3).astype(str) + ' ± '+ round(statics.iloc[2],3).astype(str)
l
# Out:
# id                   32.484 ± 18.852
# StepVelocityMean       0.994 ± 0.259
# StepVelocitySD         0.056 ± 0.025
# StepVelocityCV         6.627 ± 5.451
# StepLengthMean         0.515 ± 0.127
# StepLengthSD           0.033 ± 0.014
# StepLengthCV           7.857 ± 7.144
# StepLengthAsym         0.028 ± 0.025
# StepWidthMean          0.084 ± 0.028
# StepWidthSD            0.018 ± 0.006
# StepTimeMean         531.29 ± 89.268
# StepTimeSD           29.339 ± 26.601
# StepTimeCV             5.413 ± 4.453
# StepTimeAsym          24.726 ± 19.95
# StanceTimeMean       691.645 ± 170.3
# StanceTimeSD         36.129 ± 43.837
# StanceTimeCV           4.852 ± 4.451
# StanceTimeAsym       18.097 ± 13.107
# SwingTimeMean        372.79 ± 44.114
# SwingTimeSD          23.081 ± 12.051
# SwingTimeCV            6.445 ± 4.145
# SwingTimeAsym        17.774 ± 12.513
# Mean_GVI            114.006 ± 15.361
# WalkRatio               0.45 ± 0.118
# dtype: object

# %%
l.to_csv("/content/drive/MyDrive/Thesis/Data/l.csv")

# %% [markdown]
# ### Dataset / sex

# %%
y = np.array([pd_count-Female_count, Female_count, C_count-CFemale_count, CFemale_count])
mylabels = ["Male with PD", "Female with PD", "Male Control", "Female Control"]

plt.pie(y, labels = mylabels,autopct='%1.1f%%')
plt.title('Dataset')
plt.show()
